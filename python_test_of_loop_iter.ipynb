# %% [markdown]
# # Python Test (for loop, iter)
# 如何作答: 再題目下方新增文字或是程式碼區塊，來回答問題
#
# limit: 表示答題限制
# - P: 不能跑程式
# - G: 不能上網查

# %% [markdown]
# ## 觀念題

# %% [markdown]
# ### 1. 哪個項目最適合填入以下空格
# ```python
# for element in 空格:
#   pass # do someting
# ```
# - A: Iterator
# - B: Iterable
# - C: Sequence
# - D: Container
#
# Limit: G

# %% [markdown]
# ### 2. 是非題組 箭頭表示繼承關係，箭頭的指向為父類別

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 2.1 是Iterable 就一定是Iterator
# - 2.2 Iterator 中有兩個method?
# - 2.3 Iterator 可以實例化(instantiation)
# - 2.4 Iterable 可以實例化(instantiation)
# - 2.5 list 可以實例化(instantiation)
# - 2.6 list 是 Iterable 的 子類別
#
# Limit: PG

# %% [markdown]
# ### 3. 程式輸出判斷
# 判斷以下表達式(expression)的結果
#
# ```python
# from typing import *
#
# def ont_to_ten():
#   for i in range(1, 11):
#     yield i
#
# li1 = [1, 2, 3]
# li2 = [4, 5, 6]
#
# it = iter(li1)
# ge = one_to_ten()
#
# ```
# - 3.1
# ```python
# isinstance(it, Iterator) and iter(it) is it
# ```
#
# - 3.2
# ```python
# isinstance(li1, Iterator)
# ```
#
# - 3.3
# ```python
# isinstance(zip(li1, li2), Iterator)
# ```
# Limit: PG

# %% [markdown]
# ----
# - 3.4
# ```python
# isinstance("abc", Iterable)
# ```
# - 3.5
# ```python
# isinstance("abc", Iterator)
# ```
# - 3.6
# ```python
# isinstance(b"abc", Iterable)
# ```
# - 3.7
# ```python
# li1 + li2
# ```
# - 3.8
# ```python
# li1 * 2
# ```
#
# - 3.9
# ```python
# "a" * 5
# ```
#
# - 3.10
# ```python
# isinstance(ge, Iterator)
# ```
# Limit: NO limit

# %% [markdown]
# ### 4. 簡答
# - 4.1 如果在函式中使用yield這個保留字(reserved word)，這個函式將會回傳什麼? PG
# - 4.2 呈上，如果在該函式中使用保留字return，當成是執行到該句時，將會造成什麼影響? PG
# - 4.3 如果要表示一個Iterator之後已經沒有元素，Iterator應該要丟出什麼例外? G

# %% [markdown]
# ## 實作題

# %% [markdown]
# ### 1.MAP 函式 (NO LIMIT)
# ```map(func, *iterable) ```是一個函式會回傳一個Iterator將每個iterable中的元素做function的處裡
#
# 範例:
#
# ```python
# li = [1, 2, 3]
# def add(x):
#   return x + 1
# print(list(map(add, li)))  # [2, 3, 4]
#
# def cat(x, y):
#   return x*2 + y*3
# print(*map(cat, "abc", "def"))  # aaddd bbeee ccfff
# ```
# - 1.1 請使用Generator實作一個map，名為mymap
# - 1.2 請寫一個class實現Iterator並實作出一個map，名為MapIter

# %%
def mymap(func, *iterables):
  pass  # write your codes

# %%
from typing import Iterator
class MapIter(Iterator):
  def __init__(self, func, *iterables):
    self.func = func  # write your codes

  def __next__(self):
    pass  # write your codes

# %% [markdown]
# - 以下為測試，完成以上程式後再執行

# %%
def get_ans(iter_):
  return ','.join(iter_(lambda x, y: x*2+y*3, "abc", "def"))
ans = get_ans(map)
ans
# Out:
# 'aaddd,bbeee,ccfff'

# %%
print(ans == get_ans(mymap))
print(ans == get_ans(MapIter))
